# %% [markdown]
# %%html
# <h2> Diabetes Original dataset (not cleaned)</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original diabetes dataset
diabetes = pd.read_csv("csv.csv")
#show the dataset
display(diabetes)
# Out:
#        YEAR STATE  RATE DEATHS  \
# 0    2019.0    AL  19.8   1224
# 1    2019.0    AK  16.2    111
# 2    2019.0    AZ  23.4   2173
# 3    2019.0    AR  29.8   1144
# 4    2019.0    CA  21.8   9854
# ..      ...   ...   ...    ...
# 346  2005.0    WA  25.5  1,554
# 347  2005.0    WV  34.5    766
# 348  2005.0    WI  21.0  1,276
# 349  2005.0    WY  25.8    130
# 350     NaN   NaN   NaN    NaN
#
#                                                    URL
# 0                /nchs/pressroom/states/alabama/al.htm
# 1                 /nchs/pressroom/states/alaska/ak.htm
# 2                /nchs/pressroom/states/arizona/az.htm
# 3               /nchs/pressroom/states/arkansas/ar.htm
# 4             /nchs/pressroom/states/california/ca.htm
# ..                                                 ...
# 346   /nchs/pressroom/states/washington/washington.htm
# 347  /nchs/pressroom/states/westvirginia/westvirgin...
# 348     /nchs/pressroom/states/wisconsin/wisconsin.htm
# ...

# %%
#exploring the data to view the datatypes
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    350 non-null    float64
#  1   STATE   350 non-null    object
#  2   RATE    350 non-null    float64
#  3   DEATHS  350 non-null    object
#  4   URL     350 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 13.8+ KB

# %%
# %%html
# <h2> Cleaning Diabetes Dataset below</h2>
# Out:
# <h2> Cleaning Diabetes Dataset below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
#read the diabetes dataset
diabetes = pd.read_csv("csv.csv")
columns=['YEAR','STATE','RATE','DEATHS','URL']
#drop the column URL it is not needed
diabetes = diabetes.drop(columns='URL',axis=1)
#show the dataset
display(diabetes)
# Out:
#        YEAR STATE  RATE DEATHS
# 0    2019.0    AL  19.8   1224
# 1    2019.0    AK  16.2    111
# 2    2019.0    AZ  23.4   2173
# 3    2019.0    AR  29.8   1144
# 4    2019.0    CA  21.8   9854
# ..      ...   ...   ...    ...
# 346  2005.0    WA  25.5  1,554
# 347  2005.0    WV  34.5    766
# 348  2005.0    WI  21.0  1,276
# 349  2005.0    WY  25.8    130
# 350     NaN   NaN   NaN    NaN
#
# [351 rows x 4 columns]

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
#read diabetes dataset
diabetes = pd.read_csv("csv.csv")
#remove all non-numeric values from the column year and replace it to NaN using errors="coerce"
diabetes["YEAR"]=pd.to_numeric(diabetes["YEAR"], errors="coerce")
#dropna removes all rows with NaN in column year
diabetes = diabetes.dropna(subset=["YEAR"])
# convert the year datatype from float to integer in order to remove the zeros
diabetes["YEAR"]=diabetes["YEAR"].astype(int)
#show diabetes dataset
display(diabetes)
# Out:
#      YEAR STATE  RATE DEATHS  \
# 0    2019    AL  19.8   1224
# 1    2019    AK  16.2    111
# 2    2019    AZ  23.4   2173
# 3    2019    AR  29.8   1144
# 4    2019    CA  21.8   9854
# ..    ...   ...   ...    ...
# 345  2005    VA  22.9  1,642
# 346  2005    WA  25.5  1,554
# 347  2005    WV  34.5    766
# 348  2005    WI  21.0  1,276
# 349  2005    WY  25.8    130
#
#                                                    URL
# 0                /nchs/pressroom/states/alabama/al.htm
# 1                 /nchs/pressroom/states/alaska/ak.htm
# 2                /nchs/pressroom/states/arizona/az.htm
# 3               /nchs/pressroom/states/arkansas/ar.htm
# 4             /nchs/pressroom/states/california/ca.htm
# ..                                                 ...
# 345       /nchs/pressroom/states/virginia/virginia.htm
# 346   /nchs/pressroom/states/washington/washington.htm
# 347  /nchs/pressroom/states/westvirginia/westvirgin...
# ...

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
#read the diabetes dataset 
diabetes = pd.read_csv("csv.csv")
#change the datatype of YEAR from string to float to remove the commas
diabetes["DEATHS"]= diabetes["DEATHS"].str.replace(",","").astype(float)
#change the datatype of deaths from string to float32 to ignore the inf or na 
diabetes["DEATHS"]=diabetes["DEATHS"].astype(np.float32)
#remove all non-numeric values from the column deaths and replace it to NaN using errors="coerce"
diabetes["DEATHS"]=pd.to_numeric(diabetes["DEATHS"], errors="coerce")
#dropna removes all rows with NaN in column deaths
diabetes = diabetes.dropna(subset=["DEATHS"])
# changed the datatype of deaths from float to integer
diabetes["DEATHS"]=diabetes["DEATHS"].astype(int)
# show dataset
display(diabetes)
# Out:
#        YEAR STATE  RATE  DEATHS  \
# 0    2019.0    AL  19.8    1224
# 1    2019.0    AK  16.2     111
# 2    2019.0    AZ  23.4    2173
# 3    2019.0    AR  29.8    1144
# 4    2019.0    CA  21.8    9854
# ..      ...   ...   ...     ...
# 345  2005.0    VA  22.9    1642
# 346  2005.0    WA  25.5    1554
# 347  2005.0    WV  34.5     766
# 348  2005.0    WI  21.0    1276
# 349  2005.0    WY  25.8     130
#
#                                                    URL
# 0                /nchs/pressroom/states/alabama/al.htm
# 1                 /nchs/pressroom/states/alaska/ak.htm
# 2                /nchs/pressroom/states/arizona/az.htm
# 3               /nchs/pressroom/states/arkansas/ar.htm
# 4             /nchs/pressroom/states/california/ca.htm
# ..                                                 ...
# 345       /nchs/pressroom/states/virginia/virginia.htm
# 346   /nchs/pressroom/states/washington/washington.htm
# 347  /nchs/pressroom/states/westvirginia/westvirgin...
# ...

# %%
# %%html
# <h2 style = "color:blue; font-weight:bold"> Diabetes Dataset (cleaned) below</h2>
# Out:
# <h2 style = "color:blue; font-weight:bold"> Diabetes Dataset (cleaned) below</h2>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
#read the diabetes dataset
diabetes = pd.read_csv("csv.csv")
#display this as the title
print("\nDiabetes")
#columns from the csv file as the dataframe
columns=['YEAR','STATE','RATE','DEATHS','URL']
#drop the column URL it is not needed
diabetes = diabetes.drop(columns='URL',axis=1)
#sort the columns state and year in ascending order 
diabetes = diabetes.sort_values(['STATE','YEAR'],ascending=True)
#remove all non-numeric values from the column year and replace it to NaN using errors="coerce"
diabetes["YEAR"]=pd.to_numeric(diabetes["YEAR"], errors="coerce")
#dropna removes all rows with NaN in column year
diabetes = diabetes.dropna(subset=["YEAR"])
# convert the year datatype from float to integer in order to remove the zeros
diabetes["YEAR"]=diabetes["YEAR"].astype(int)
#change the datatype of YEAR from string to float to remove the commas
diabetes["DEATHS"]= diabetes["DEATHS"].str.replace(",","").astype(float)
#convert the column deaths to float32
diabetes["DEATHS"]=diabetes["DEATHS"].astype(np.float32)
#remove all non-numeric values from the column deaths and replace it to NaN using errors="coerce"
diabetes["DEATHS"]=pd.to_numeric(diabetes["DEATHS"], errors="coerce")
#dropna removes all rows with NaN in column deaths
diabetes = diabetes.dropna(subset=["DEATHS"])
#convert the deaths datatype from string to integer in order to remove the zeros
diabetes["DEATHS"]=diabetes["DEATHS"].astype(int)
# show the diabetes dataset
display(diabetes)
# Out:
# Diabetes
#      YEAR STATE  RATE  DEATHS
# 301  2005    AK  22.4      93
# 251  2014    AK  19.4     113
# 201  2015    AK  23.9     142
# 151  2016    AK  19.3     124
# 101  2017    AK  19.3     130
# ..    ...   ...   ...     ...
# 249  2015    WY  20.8     136
# 199  2016    WY  16.6     112
# 149  2017    WY  18.1     121
# 99   2018    WY  21.4     145
# 49   2019    WY  18.5     132
#
# [350 rows x 4 columns]

# %%
# saved the cleaned dataset as a new csv file
diabetes.to_csv(r'/Users/euniceolorunshola/Desktop/Big data programming/Class Project/Datasets(clean)/diabetescleaned.csv')
print(diabetes)
# Out:
#      YEAR STATE  RATE  DEATHS
# 301  2005    AK  22.4      93
# 251  2014    AK  19.4     113
# 201  2015    AK  23.9     142
# 151  2016    AK  19.3     124
# 101  2017    AK  19.3     130
# ..    ...   ...   ...     ...
# 249  2015    WY  20.8     136
# 199  2016    WY  16.6     112
# 149  2017    WY  18.1     121
# 99   2018    WY  21.4     145
# 49   2019    WY  18.5     132
#
# [350 rows x 4 columns]

# %%
# %%html
# <h2> Occupant and Alcohol Impaired Driving Deaths Original dataset (not cleaned) below </h2>
# Out:
# <h2> Occupant and Alcohol Impaired Driving Deaths Original dataset (not cleaned) below </h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original occupant and alcohol impaired driving deaths dataset
occupant_alcohol_deaths = pd.read_csv("Occupant_and_Alcohol-Impaired_Driving_Deaths_in_States__2005-2014.csv")
#show the dataset
display(occupant_alcohol_deaths)
# Out:
#    State   Alcohol-Impaired Driving Deaths   Occupant Deaths   \
# 0     WY                               484               1195
# 1     NC                              3996              10093
# 2     OR                              1129               2735
# 3     NY                              3605               7013
# 4     AL                              2997               7754
# 5     RI                               265                429
# 6     WI                              2300               4572
# 7     PA                              4355               9656
# 8     NJ                              1747               3832
# 9     VA                              2518               6335
# 10    TX                             13171              24013
# 11    DE                               430                767
# 12    MA                              1309               2465
# 13    NV                               968               1962
# ...

# %%
#exploring the data in order to know the datatypes and check how many records
occupant_alcohol_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State                             51 non-null     object
#  1    Alcohol-Impaired Driving Deaths  51 non-null     int64
#  2    Occupant Deaths                  51 non-null     int64
#  3   Location                          51 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.7+ KB

# %%
# %%html
# <h2> Cleaning Occupant and Alcohol impaired deaths Dataset below</h2>
# Out:
# <h2> Cleaning Occupant and Alcohol impaired deaths Dataset below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#read the occupant and alcohol imparied driving deaths dataset
occupant_alcohol_deaths = pd.read_csv("Occupant_and_Alcohol-Impaired_Driving_Deaths_in_States__2005-2014.csv")
columns = ['State', 'Alcohol-Impaired Driving Deaths', 'Occupant Deaths', 'Location']
#sort the state column in ascending order
occupant_alcohol_deaths = occupant_alcohol_deaths.sort_values('State', ascending=True)
# show the dataset
display(occupant_alcohol_deaths)
# Out:
#    State   Alcohol-Impaired Driving Deaths   Occupant Deaths   \
# 41    AK                               205                439
# 4     AL                              2997               7754
# 26    AR                              1636               4526
# 50    AZ                              2656               5712
# 43    CA                              9791              20733
# 44    CO                              1599               3521
# 32    CT                              1049               1806
# 29    DC                                96                130
# 11    DE                               430                767
# 27    FL                              8053              16041
# 30    GA                              3513              10406
# 25    HI                               453                587
# 16    IA                               967               2970
# 35    ID                               661               1725
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#read the occupant and alcohol imparied driving deaths dataset
occupant_alcohol_deaths = pd.read_csv("Occupant_and_Alcohol-Impaired_Driving_Deaths_in_States__2005-2014.csv")
columns = ['State', 'Alcohol-Impaired Driving Deaths', 'Occupant Deaths', 'Location']
#drop the column location it is not needed, it is basically like state column and with no specified location
occupant_alcohol_deaths = occupant_alcohol_deaths.drop(columns='Location',axis=1)
# show the dataset
display(occupant_alcohol_deaths)
# Out:
#    State   Alcohol-Impaired Driving Deaths   Occupant Deaths
# 0     WY                               484               1195
# 1     NC                              3996              10093
# 2     OR                              1129               2735
# 3     NY                              3605               7013
# 4     AL                              2997               7754
# 5     RI                               265                429
# 6     WI                              2300               4572
# 7     PA                              4355               9656
# 8     NJ                              1747               3832
# 9     VA                              2518               6335
# 10    TX                             13171              24013
# 11    DE                               430                767
# 12    MA                              1309               2465
# 13    NV                               968               1962
# ...

# %%
# %%html
# <h2 style = "color:green; font-weight:bold"> Occupant and Alcohol Impaired Driving Deaths Dataset (cleaned) below</h2>
# Out:
# <h2 style = "color:green; font-weight:bold"> Occupant and Alcohol Impaired Driving Deaths Dataset (cleaned) below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
#read the occupant and alcohol imparied driving deaths dataset
occupant_alcohol_deaths = pd.read_csv("Occupant_and_Alcohol-Impaired_Driving_Deaths_in_States__2005-2014.csv")
#display this as the title
print("\nOccupant and Alcohol-Impaired Driving Deaths")
columns = ['State', 'Alcohol-Impaired Driving Deaths', 'Occupant Deaths', 'Location']
#sort the state column in ascending order
occupant_alcohol_deaths = occupant_alcohol_deaths.sort_values('State', ascending=True)
#drop the column location it is not needed, it is basically like state column and with no specified location
occupant_alcohol_deaths = occupant_alcohol_deaths.drop(columns='Location',axis=1)
# show the dataset
display(occupant_alcohol_deaths)
# Out:
# Occupant and Alcohol-Impaired Driving Deaths
#    State   Alcohol-Impaired Driving Deaths   Occupant Deaths
# 41    AK                               205                439
# 4     AL                              2997               7754
# 26    AR                              1636               4526
# 50    AZ                              2656               5712
# 43    CA                              9791              20733
# 44    CO                              1599               3521
# 32    CT                              1049               1806
# 29    DC                                96                130
# 11    DE                               430                767
# 27    FL                              8053              16041
# 30    GA                              3513              10406
# 25    HI                               453                587
# 16    IA                               967               2970
# ...

# %%
# saved the cleaned dataset as a new csv file
occupant_alcohol_deaths.to_csv(r'/Users/euniceolorunshola/Desktop/Big data programming/Class Project/Datasets(clean)/occupant_alcohol-impaired_driving_deaths_datasetscleaned.csv')
print(occupant_alcohol_deaths)
# Out:
#    State   Alcohol-Impaired Driving Deaths   Occupant Deaths
# 41    AK                               205                439
# 4     AL                              2997               7754
# 26    AR                              1636               4526
# 50    AZ                              2656               5712
# 43    CA                              9791              20733
# 44    CO                              1599               3521
# 32    CT                              1049               1806
# 29    DC                                96                130
# 11    DE                               430                767
# 27    FL                              8053              16041
# 30    GA                              3513              10406
# 25    HI                               453                587
# 16    IA                               967               2970
# 35    ID                               661               1725
# ...

# %%
# %%html
# <h2> Traffic Violations Original dataset (not cleaned) below</h2>
# Out:
# <h2> Traffic Violations Original dataset (not cleaned) below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original traffic violations dataset
trafficviolations = pd.read_csv("Traffic_Violations.csv")
#show dataset
display(trafficviolations)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Date Of Stop Time Of Stop Agency  \
# 0         09/24/2013     17:11:00    MCP
# 1         12/20/2012     00:41:00    MCP
# 2         07/20/2012     23:12:00    MCP
# 3         03/19/2012     16:10:00    MCP
# 4         12/01/2014     12:52:00    MCP
# ...              ...          ...    ...
# 1018629   12/22/2016     23:27:00    MCP
# 1018630   12/20/2016     12:01:00    MCP
# 1018631   12/21/2016     02:11:00    MCP
# 1018632   12/26/2016     08:07:00    MCP
# 1018633   12/27/2016     22:15:00    MCP
#
#                                                SubAgency  \
# 0                            3rd district, Silver Spring
# 1                                 2nd district, Bethesda
# ...

# %%
#exploring the data in order to know the datatypes and check how many record
trafficviolations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018634 entries, 0 to 1018633
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Date Of Stop             1018634 non-null  object
#  1   Time Of Stop             1018634 non-null  object
#  2   Agency                   1018634 non-null  object
#  3   SubAgency                1018634 non-null  object
#  4   Description              1018625 non-null  object
#  5   Location                 1018632 non-null  object
#  6   Latitude                 933599 non-null   float64
#  7   Longitude                933599 non-null   float64
#  8   Accident                 1018634 non-null  object
#  9   Belts                    1018634 non-null  object
#  10  Personal Injury          1018634 non-null  object
#  11  Property Damage          1018634 non-null  object
#  12  Fatal                    1018634 non-null  object
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#read the traffic violations dataset
trafficviolations = pd.read_csv("Traffic_Violations.csv")
columns = ['Date of Stop', 'Description', 'Location', 'Accident', 'Belts', 'Personal Injury', 'Property Damage','Fatal', 'Alcohol', 'State','Year', 'Race','Gender','Driver City','Arrest Type']
#sort the arrest type column in ascending order
trafficviolations = trafficviolations.sort_values('Arrest Type', ascending=True)
# show the dataset
display(trafficviolations)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Date Of Stop Time Of Stop Agency                    SubAgency  \
# 0        09/24/2013     17:11:00    MCP  3rd district, Silver Spring
# 690161   05/15/2014     11:04:00    MCP     5th district, Germantown
# 690162   05/27/2014     09:35:00    MCP     5th district, Germantown
# 690163   05/27/2014     09:58:00    MCP     5th district, Germantown
# 690164   06/24/2014     07:42:00    MCP     5th district, Germantown
# ...             ...          ...    ...                          ...
# 367905   06/21/2012     12:46:00    MCP       2nd district, Bethesda
# 569927   07/26/2012     16:41:00    MCP       2nd district, Bethesda
# 478429   11/15/2013     08:42:00    MCP       2nd district, Bethesda
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#read the traffic violations dataset
trafficviolations = pd.read_csv("Traffic_Violations.csv")
columns = ['Date Of Stop', 'Time Of Stop','Agency','SubAgency','Description', 'Location', 'Latitude','Longitude','Accident', 'Belts', 'Personal Injury', 'Property Damage','Fatal', 'Commercial License','HAZMAT','Commercial Vehicle','Alcohol', 'Work Zone','State','VehicleType','Year', 'Make','Model','Color', 'Violation Type','Charge','Article','Contributed To Accident', 'Race','Gender','Driver City','Driver State','DL State', 'Arrest Type','Geolocation']
#drop the columns that are not needed
trafficviolations = trafficviolations.drop(columns=['Time Of Stop','Agency', 'SubAgency','Latitude', 'Longitude', 'Commercial License','HAZMAT','Commercial Vehicle','Work Zone', 'VehicleType','Make','Model','Color','Charge','Article','DL State','Geolocation'], axis=1)
#drop the defined columns that contains NaN 
trafficviolations.dropna(subset=['Date Of Stop', 'Description','Location','Accident','Belts','Personal Injury','Property Damage','Fatal','State','Year','Violation Type','Contributed To Accident','Race','Gender','Driver City','Driver State','Arrest Type'])
#sort the values by the columns but not in order to make it correlate with the other columns
trafficviolations = trafficviolations.sort_values(by=['Date Of Stop','Location','Driver City'], ascending=False)
#remove all non-numeric values from the column year and replace it to NaN using errors="coerce"
trafficviolations["Year"]=pd.to_numeric(trafficviolations["Year"], errors="coerce")
#remove any NaN or missing values defined in the year column
trafficviolations = trafficviolations.dropna(subset=["Year"])
# convert the year datatype from float to integer in order to remove the zeros
trafficviolations["Year"]=trafficviolations["Year"].astype(int)
#show dataset
display(trafficviolations)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Date Of Stop                                        Description  \
# 787692   12/31/2015  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 954816   12/31/2015                  DRIVER CHANGING LANES WHEN UNSAFE
# 787695   12/31/2015  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 509490   12/31/2015  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 970642   12/31/2015         EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH
# ...             ...                                                ...
# 71590    01/01/2012         PARKING WHERE PROHIBITED BY OFFICIAL SIGNS
# 809428   01/01/2012                  DRIVER CHANGING LANES WHEN UNSAFE
# 809429   01/01/2012         EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH
# ...

# %%
# %%html
# <h2 style = "color:brown; font-weight:bold"> Traffic Violations  Dataset (cleaned) below</h2>
# Out:
# <h2 style = "color:brown; font-weight:bold"> Traffic Violations  Dataset (cleaned) below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#read the traffic violations dataset
trafficviolations = pd.read_csv("Traffic_Violations.csv")
#display this as the title
print("\nTraffic Violations")
columns = ['Date of Stop', 'Time Of Stop','Agency','SubAgency','Description', 'Location', 'Latitude','Longitude','Accident', 'Belts', 'Personal Injury', 'Property Damage','Fatal', 'Commercial License','HAZMAT','Commercial Vehicle','Alcohol', 'Work Zone','State','VehicleType','Year', 'Make','Model','Color', 'Violation Type','Charge','Article','Contributed To Accident', 'Race','Gender','Driver City','Driver State','DL State', 'Arrest Type','Geolocation']
#sort the arrest type column in ascending order
trafficviolations = trafficviolations.sort_values('Arrest Type', ascending=True)
#drop the columns that are not needed
trafficviolations = trafficviolations.drop(columns=['Time Of Stop','Agency', 'SubAgency','Latitude', 'Longitude', 'Commercial License','HAZMAT','Commercial Vehicle','Work Zone', 'VehicleType','Make','Model','Color','Charge','Article','DL State','Geolocation'], axis=1)
#checks in the defined columns to look for missing values and drops it
trafficviolations.dropna(subset=['Date Of Stop', 'Description','Location','Accident','Belts','Personal Injury','Property Damage','Fatal','State','Year','Violation Type','Contributed To Accident','Race','Gender','Driver City','Driver State','Arrest Type'])
#sort the columns date of stop, location, and driver city in descending order
trafficviolations = trafficviolations.sort_values(by=['Date Of Stop','Location','Driver City'], ascending=False)
#remove all non-numeric values from the column year and replace it to NaN using errors="coerce"
trafficviolations["Year"]=pd.to_numeric(trafficviolations["Year"], errors="coerce")
#dropna removes all rows with NaN in column year
trafficviolations = trafficviolations.dropna(subset=["Year"])
# convert the year datatype from float to integer in order to remove the zeros
trafficviolations["Year"]=trafficviolations["Year"].astype(int)
# show the dataset
display(trafficviolations)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Traffic Violations
#        Date Of Stop                                        Description  \
# 787692   12/31/2015  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 954816   12/31/2015                  DRIVER CHANGING LANES WHEN UNSAFE
# 787695   12/31/2015  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 509490   12/31/2015  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 970642   12/31/2015         EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH
# ...             ...                                                ...
# 71590    01/01/2012         PARKING WHERE PROHIBITED BY OFFICIAL SIGNS
# 809428   01/01/2012                  DRIVER CHANGING LANES WHEN UNSAFE
# ...

# %%
# saved the cleaned dataset as a new csv file
trafficviolations.to_csv(r'/Users/euniceolorunshola/Desktop/Big data programming/Class Project/Datasets(clean)/TrafficViolations_datasetscleaned.csv')
print(trafficviolations)
# Out:
#        Date Of Stop                                        Description  \
# 787692   12/31/2015  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 954816   12/31/2015                  DRIVER CHANGING LANES WHEN UNSAFE
# 787695   12/31/2015  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 509490   12/31/2015  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 970642   12/31/2015         EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH
# ...             ...                                                ...
# 71590    01/01/2012         PARKING WHERE PROHIBITED BY OFFICIAL SIGNS
# 809428   01/01/2012                  DRIVER CHANGING LANES WHEN UNSAFE
# 809429   01/01/2012         EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH
# 700891   01/01/2012  DRIVER FAILURE TO OBEY DESIGNATED LANE DIRECTIONS
# 72534    01/01/2012  PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUB...
#
#                                 Location Accident Belts Personal Injury  \
# ...

# %%
# %%html
# <h2> Personal Income Original dataset (not cleaned) below </h2>
# Out:
# <h2> Personal Income Original dataset (not cleaned) below </h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original personal income dataset
personal_income = pd.read_csv("Personal Income.csv")
#show dataset
display(personal_income)
# Out:
#      Posting Date Day of the Week   Amount     Category       Description  \
# 0          8/3/18          Friday -1360.00        Bills              Rent
# 1          8/4/18        Saturday  -117.89    Groceries               NaN
# 2          8/4/18        Saturday   -34.27  Merchandise  Makeup/Skin Care
# 3          8/4/18        Saturday   -21.59  Merchandise            Amazon
# 4          8/5/18          Sunday   -10.79  Merchandise            Amazon
# ...           ...             ...      ...          ...               ...
# 1014      9/30/19          Monday  -420.00        Bills              Rent
# 1015      9/30/19          Monday   -19.35  Merchandise            Amazon
# 1016      9/30/19          Monday   -16.14  Merchandise           Clothes
# 1017      9/30/19          Monday   -10.35    Uber/Lyft               NaN
# 1018      9/30/19          Monday    -8.63  Merchandise            Amazon
#
#                             Source
# 0                 Chase Debit Card
# ...

# %%
#exploring the data in order to know the datatypes and check how many records
personal_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Posting Date     1019 non-null   object
#  1   Day of the Week  1019 non-null   object
#  2   Amount           1019 non-null   float64
#  3   Category         1019 non-null   object
#  4   Description      506 non-null    object
#  5   Source           1019 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 47.9+ KB

# %%
# %%html
# <h2> Cleaning Personal Income Dataset below</h2>
# Out:
# <h2> Cleaning Personal Income Dataset below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original diabetes dataset
personal_income = pd.read_csv("Personal Income.csv")
#renamed column Amount to Amount Spent
personal_income.rename(columns = {'Amount': 'Amount Spent'}, inplace=True)
#renamed column Source to Payment Method
personal_income.rename(columns = {'Source': 'Payment Method'}, inplace=True)
columns = ['Posting Date', 'Day of the Week', 'Amount Spent', 'Category', 'Description', 'Payment Method']
#sort the posting date and day of the week column in order
personal_income = personal_income.sort_values(by=['Posting Date','Day of the Week'], ascending=True)
#show the dataset
display(personal_income)
# Out:
#     Posting Date Day of the Week  Amount Spent     Category       Description  \
# 205       1/1/19         Tuesday        -16.20  Merchandise  Makeup/Skin Care
# 235      1/10/19        Thursday         -9.14    Uber/Lyft               NaN
# 236      1/11/19          Friday        -44.40        Bills             Phone
# 237      1/11/19          Friday         -8.03    Uber/Lyft               NaN
# 238      1/11/19          Friday         13.99  Merchandise            Amazon
# ..           ...             ...           ...          ...               ...
# 926       9/9/19          Monday        -12.10    Uber/Lyft               NaN
# 927       9/9/19          Monday        -11.45    Uber/Lyft               NaN
# 928       9/9/19          Monday        -10.66  Merchandise            Amazon
# 929       9/9/19          Monday         -7.75    Uber/Lyft               NaN
# 930       9/9/19          Monday          8.71    Uber/Lyft               NaN
#
#            Payment Method
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original diabetes dataset
personal_income = pd.read_csv("Personal Income.csv")
#renamed column Amount to Amount Spent
personal_income.rename(columns = {'Amount': 'Amount Spent'}, inplace=True)
#renamed column Source to Payment Method
personal_income.rename(columns = {'Source': 'Payment Method'}, inplace=True)
columns = ['Posting Date', 'Day of the Week', 'Amount Spent', 'Category', 'Description', 'Payment Method']
#converted column Amount spent from float to string
personal_income["Amount Spent"]= personal_income["Amount Spent"].astype(str)
# showed the modified datatypes to show that amount spent is now a string
display(personal_income.dtypes)
#removed the - sign from the column Amount Spent
personal_income["Amount Spent"]= personal_income["Amount Spent"].str.replace("-","").astype(float)
# show the dataset
display(personal_income)
# Out:
# Posting Date       object
# Day of the Week    object
# Amount Spent       object
# Category           object
# Description        object
# Payment Method     object
# dtype: object
#      Posting Date Day of the Week  Amount Spent     Category  \
# 0          8/3/18          Friday       1360.00        Bills
# 1          8/4/18        Saturday        117.89    Groceries
# 2          8/4/18        Saturday         34.27  Merchandise
# 3          8/4/18        Saturday         21.59  Merchandise
# 4          8/5/18          Sunday         10.79  Merchandise
# ...           ...             ...           ...          ...
# 1014      9/30/19          Monday        420.00        Bills
# 1015      9/30/19          Monday         19.35  Merchandise
# 1016      9/30/19          Monday         16.14  Merchandise
# 1017      9/30/19          Monday         10.35    Uber/Lyft
# 1018      9/30/19          Monday          8.63  Merchandise
#
#            Description                Payment Method
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original diabetes dataset
personal_income = pd.read_csv("Personal Income.csv")
#renamed column Amount to Amount Spent
personal_income.rename(columns = {'Amount': 'Amount Spent'}, inplace=True)
#renamed column Source to Payment Method
personal_income.rename(columns = {'Source': 'Payment Method'}, inplace=True)
columns = ['Posting Date', 'Day of the Week', 'Amount Spent', 'Category', 'Description', 'Payment Method']
#dropna removes all rows with NaN in column Description
personal_income = personal_income.dropna(subset=["Description"])
#replace Makeup/Skin Care in description column to Cosemetics in order to keep the data clean without / sign
personal_income["Description"].replace({"Makeup/Skin Care": "Cosmetics"}, inplace=True)
#show dataset
display(personal_income)
# Out:
#      Posting Date Day of the Week  Amount Spent     Category Description  \
# 0          8/3/18          Friday      -1360.00        Bills        Rent
# 2          8/4/18        Saturday        -34.27  Merchandise   Cosmetics
# 3          8/4/18        Saturday        -21.59  Merchandise      Amazon
# 4          8/5/18          Sunday        -10.79  Merchandise      Amazon
# 5         8/10/18          Friday        -30.78  Merchandise      Amazon
# ...           ...             ...           ...          ...         ...
# 1012      9/28/19        Saturday         -5.39  Merchandise      Amazon
# 1014      9/30/19          Monday       -420.00        Bills        Rent
# 1015      9/30/19          Monday        -19.35  Merchandise      Amazon
# 1016      9/30/19          Monday        -16.14  Merchandise     Clothes
# 1018      9/30/19          Monday         -8.63  Merchandise      Amazon
#
#                     Payment Method
# 0                 Chase Debit Card
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original diabetes dataset
personal_income = pd.read_csv("Personal Income.csv")
#renamed column Amount to Amount Spent
personal_income.rename(columns = {'Amount': 'Amount Spent'}, inplace=True)
#renamed column Source to Payment Method
personal_income.rename(columns = {'Source': 'Payment Method'}, inplace=True)
columns = ['Posting Date', 'Day of the Week', 'Amount Spent', 'Category', 'Description', 'Payment Method']
#dropna removes all rows with NaN in column Description
personal_income = personal_income.dropna(subset=["Description"])
#replace Makeup/Skin Care in description column to Cosemetics in order to keep the data clean without / sign
personal_income["Description"].replace({"Makeup/Skin Care": "Cosmetics"}, inplace=True)
#checks in the defined column description to look for missing values and drops it
personal_income.dropna(subset=['Description'])
display(personal_income)
# Out:
#      Posting Date Day of the Week  Amount Spent     Category Description  \
# 0          8/3/18          Friday      -1360.00        Bills        Rent
# 2          8/4/18        Saturday        -34.27  Merchandise   Cosmetics
# 3          8/4/18        Saturday        -21.59  Merchandise      Amazon
# 4          8/5/18          Sunday        -10.79  Merchandise      Amazon
# 5         8/10/18          Friday        -30.78  Merchandise      Amazon
# ...           ...             ...           ...          ...         ...
# 1012      9/28/19        Saturday         -5.39  Merchandise      Amazon
# 1014      9/30/19          Monday       -420.00        Bills        Rent
# 1015      9/30/19          Monday        -19.35  Merchandise      Amazon
# 1016      9/30/19          Monday        -16.14  Merchandise     Clothes
# 1018      9/30/19          Monday         -8.63  Merchandise      Amazon
#
#                     Payment Method
# 0                 Chase Debit Card
# ...

# %%
# %%html
# <h2 style = "color:gold; font-weight:bold"> Personal Income  Dataset (cleaned) below</h2>
# Out:
# <h2 style = "color:gold; font-weight:bold"> Personal Income  Dataset (cleaned) below</h2>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
#showing original diabetes dataset
personal_income = pd.read_csv("Personal Income.csv")
#display this as the title
print("\nPersonal Income")
#renamed column Amount to Amount Spent
personal_income.rename(columns = {'Amount': 'Amount Spent'}, inplace=True)
#renamed column Source to Payment Method
personal_income.rename(columns = {'Source': 'Payment Method'}, inplace=True)
columns = ['Posting Date', 'Day of the Week', 'Amount Spent', 'Category', 'Description', 'Payment Method']
#sort the posting date and day of the week column in order
personal_income = personal_income.sort_values(by=['Posting Date','Day of the Week'], ascending=True)
#converted column Amount spent from float to string
personal_income["Amount Spent"]= personal_income["Amount Spent"].astype(str)
#removed the - sign from the column Amount Spent
personal_income["Amount Spent"]= personal_income["Amount Spent"].str.replace("-","").astype(float)
#dropna removes all rows with NaN in column Description
personal_income = personal_income.dropna(subset=["Description"])
#replace Makeup/Skin Care in description column to Cosemetics in order to keep the data clean without / sign
personal_income["Description"].replace({"Makeup/Skin Care": "Cosmetics"}, inplace=True)
#checks in the defined column description to look for missing values and drops it
personal_income.dropna(subset=['Description'])
#show the dataset
display(personal_income)
# Out:
# Personal Income
#     Posting Date Day of the Week  Amount Spent     Category Description  \
# 205       1/1/19         Tuesday         16.20  Merchandise   Cosmetics
# 236      1/11/19          Friday         44.40        Bills       Phone
# 238      1/11/19          Friday         13.99  Merchandise      Amazon
# 239      1/13/19          Sunday         24.98  Merchandise      Amazon
# 240      1/14/19          Monday        372.59  Merchandise    Best Buy
# ..           ...             ...           ...          ...         ...
# 919       9/9/19          Monday         44.40        Bills       Phone
# 921       9/9/19          Monday         27.02  Merchandise     Clothes
# 922       9/9/19          Monday         25.00         Food  Super Card
# 924       9/9/19          Monday         20.40        Other     Driving
# 928       9/9/19          Monday         10.66  Merchandise      Amazon
#
#            Payment Method
# 205  Discover Credit Card
# 236      Chase Debit Card
# ...

# %%
# saved the cleaned dataset as a new csv file
personal_income.to_csv(r'/Users/euniceolorunshola/Desktop/Big data programming/Class Project/Datasets(clean)/Personal_Income_datasetscleaned.csv')
print(personal_income)
# Out:
#     Posting Date Day of the Week  Amount Spent     Category Description  \
# 205       1/1/19         Tuesday         16.20  Merchandise   Cosmetics
# 236      1/11/19          Friday         44.40        Bills       Phone
# 238      1/11/19          Friday         13.99  Merchandise      Amazon
# 239      1/13/19          Sunday         24.98  Merchandise      Amazon
# 240      1/14/19          Monday        372.59  Merchandise    Best Buy
# ..           ...             ...           ...          ...         ...
# 919       9/9/19          Monday         44.40        Bills       Phone
# 921       9/9/19          Monday         27.02  Merchandise     Clothes
# 922       9/9/19          Monday         25.00         Food  Super Card
# 924       9/9/19          Monday         20.40        Other     Driving
# 928       9/9/19          Monday         10.66  Merchandise      Amazon
#
#            Payment Method
# 205  Discover Credit Card
# 236      Chase Debit Card
# ...
